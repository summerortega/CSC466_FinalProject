# %%
import pandas as pd
import numpy as np

from pathlib import Path

# %%
csv_name = "raw_dog_traits_table_2013_2025.csv"

for base_dir in [Path.cwd(), *Path.cwd().parents]:
    csv_path = base_dir / "data" / "raw" / csv_name
    if csv_path.exists():
        break
else:
    raise FileNotFoundError(
        f"Could not find {csv_name} under a data/raw directory starting from {Path.cwd()}"
    )

# %%
raw_df = pd.read_csv(csv_path)
raw_df
# Out:
#                            Breed               Group  2013 Rank  2014 Rank  \
# 0                  Affenpinscher           Toy Group      143.0      144.0
# 1                   Afghan Hound         Hound Group       95.0       98.0
# 2               Airedale Terrier       Terrier Group       56.0       57.0
# 3                          Akita       Working Group       45.0       46.0
# 4               Alaskan Malamute       Working Group       57.0       54.0
# ..                           ...                 ...        ...        ...
# 197             Wire Fox Terrier       Terrier Group       96.0       95.0
# 198  Wirehaired Pointing Griffon      Sporting Group       80.0       76.0
# 199            Wirehaired Vizsla      Sporting Group        NaN      107.0
# 200               Xoloitzcuintli  Non-Sporting Group      139.0      142.0
# 201            Yorkshire Terrier           Toy Group        6.0        6.0
#
# ...

# %%
breed_group = raw_df[['Breed', 'Group']]
breed_group
# Out:
#                            Breed               Group
# 0                  Affenpinscher           Toy Group
# 1                   Afghan Hound         Hound Group
# 2               Airedale Terrier       Terrier Group
# 3                          Akita       Working Group
# 4               Alaskan Malamute       Working Group
# ..                           ...                 ...
# 197             Wire Fox Terrier       Terrier Group
# 198  Wirehaired Pointing Griffon      Sporting Group
# 199            Wirehaired Vizsla      Sporting Group
# 200               Xoloitzcuintli  Non-Sporting Group
# 201            Yorkshire Terrier           Toy Group
#
# [202 rows x 2 columns]

# %%
rank_cols = [f'{year} Rank' for year in range(2013, 2026)]
breed_rank = raw_df[['Breed', *rank_cols]]
breed_rank
# Out:
#                            Breed  2013 Rank  2014 Rank  2015 Rank  2016 Rank  \
# 0                  Affenpinscher      143.0      144.0      136.0      149.0
# 1                   Afghan Hound       95.0       98.0      100.0      113.0
# 2               Airedale Terrier       56.0       57.0       53.0       55.0
# 3                          Akita       45.0       46.0       46.0       46.0
# 4               Alaskan Malamute       57.0       54.0       54.0       59.0
# ..                           ...        ...        ...        ...        ...
# 197             Wire Fox Terrier       96.0       95.0       94.0      101.0
# 198  Wirehaired Pointing Griffon       80.0       76.0       66.0       66.0
# 199            Wirehaired Vizsla        NaN      107.0      156.0      157.0
# 200               Xoloitzcuintli      139.0      142.0      135.0      139.0
# 201            Yorkshire Terrier        6.0        6.0        7.0        9.0
#
# ...

# %%
breed_traits = raw_df[["Breed", *raw_df.columns[17:]]]
breed_traits
# Out:
#                            Breed  Good With Young Children  \
# 0                  Affenpinscher                         3
# 1                   Afghan Hound                         3
# 2               Airedale Terrier                         3
# 3                          Akita                         3
# 4               Alaskan Malamute                         3
# ..                           ...                       ...
# 197             Wire Fox Terrier                         5
# 198  Wirehaired Pointing Griffon                         5
# 199            Wirehaired Vizsla                         5
# 200               Xoloitzcuintli                         3
# 201            Yorkshire Terrier                         5
#
#      Good With Other Dogs  Shedding Level  Coat Grooming Frequency  \
# 0                       3               3                        3
# 1                       3               1                        4
# ...
